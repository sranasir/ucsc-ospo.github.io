# %% [markdown]
# ## 1. Install Sciunit software

# %%
# !pip install sciunit2
# Out:
# ...
#   Using cached sciunit2-0.4.post58.dev224550607-py3-none-any.whl (830 kB)
# Processing /home/jovyan/.cache/pip/wheels/3e/63/83/28b90bed614474858ca1d8c95116b4c13e59ce00f640ea3152/scandir-1.10.0-cp37-cp37m-linux_x86_64.whl
# Processing /home/jovyan/.cache/pip/wheels/eb/b8/d0/93dffd6fc67277d00c4a72deb9e259ab10a9d6f4ac2cf7cede/hs_restclient-1.3.7-py3-none-any.whl
# ...
#   Using cached retry-0.9.2-py2.py3-none-any.whl (8.0 kB)
# ...
#   Using cached humanfriendly-8.2-py2.py3-none-any.whl (86 kB)
# Processing /home/jovyan/.cache/pip/wheels/47/6c/04/0439c496a6f6412eaecdfa978c80732d52a65a1bcc5c5856b3/utcdatetime-0.0.7-py3-none-any.whl
# ...
#      |████████████████████████████████| 70 kB 529 kB/s eta 0:00:011
# ...
#   Using cached backports.tempfile-1.0-py2.py3-none-any.whl (4.4 kB)
# ...
#   Using cached tzlocal-2.1-py2.py3-none-any.whl (16 kB)
# ...
#   Using cached zipfile2-0.0.12-py2.py3-none-any.whl (44 kB)
# ...
#   Using cached contextlib2-0.6.0.post1-py2.py3-none-any.whl (9.8 kB)
# ...

# %% [markdown]
# * We tested this notebook using <font color='red'> sciunit2 0.4.post58.dev224550607 </font> version of Sciunit

# %%
# !sciunit --version
# Out:
# sciunit2 0.4.post58.dev224550607

# %% [markdown]
# ## 2. Create a Sciunit Container

# %% [markdown]
# ### 2.1 Convert Step-1 Contents to Python file (*.py)

# %% [markdown]
# The current version of Sciunit cannot create a Sciunit container using Jupyter notebook. So we need to convert the first Jupyter notebok to Python code (from *.ipynb to *.py).

# %%
# !pip install jupyter_contrib_nbextensions

# %%
notebook_name = 'HAND_py3'
# !jupyter nbconvert {notebook_name}.ipynb --to script
# Out:
# [NbConvertApp] Converting notebook HAND_py3.ipynb to script
# [NbConvertApp] Writing 11481 bytes to HAND_py3.py

# %%
# delete the process of unzipping the `onion-hand_new.zip`
python_name = notebook_name+".py"
modified_python_name = "Modified_" + python_name
with open(python_name, 'r') as fin, open(modified_python_name, 'w+') as fout:
    for i, l in enumerate(fin):
        if int(31) <= i < int(375):
            fout.write("%s\n"%l)

# %% [markdown]
# ### 2.2 Create an empty Sciunit Container

# %%
package_name = "HAND"
# !sciunit create {package_name}
# Out:
# Opened empty sciunit at /home/jovyan/sciunit/HAND

# %% [markdown]
# ### 2.3 Open the empty Sciunit Container

# %%
# !sciunit open {package_name}
# Out:
# Switched to sciunit 'HAND'

# %% [markdown]
# ### 2.4 Execute Sciunit to create the Sciunit Container

# %%
# %%writefile hand_sciunit.sh
# #!/bin/bash
# eval "$(conda shell.bash hook)"
# conda activate taudem
# sciunit exec ipython HAND_py3.py
# Out:
# Writing hand_sciunit.sh

# %%
# %%time
# !/bin/bash hand_sciunit.sh
# Out:
# Provenance log file: /home/jovyan/work/examples/HAND/cde-package/provenance.cde-root.2.log
# CDE WARNING (unsupported operation): sys_openat 'data/onion-hand/find_inlets/compile-on-roger.sh' is a relative path and dirfd != AT_FDCWD
# CDE WARNING (unsupported operation): sys_openat 'data/onion-hand/find_inlets/CMakeLists.txt' is a relative path and dirfd != AT_FDCWD
# CDE WARNING (unsupported operation): sys_openat 'data/onion-hand/find_inlets/LICENSE' is a relative path and dirfd != AT_FDCWD
# CDE WARNING (unsupported operation): sys_openat 'data/onion-hand/find_inlets/src/find_inlets_hr.cpp' is a relative path and dirfd != AT_FDCWD
# CDE WARNING (unsupported operation): sys_openat 'data/onion-hand/find_inlets/src/find_inlets.cpp' is a relative path and dirfd != AT_FDCWD
# CDE WARNING (unsupported operation): sys_openat 'data/onion-hand/find_inlets/build/CMakeFiles/progress.marks' is a relative path and dirfd != AT_FDCWD
# ...

# %% [markdown]
# ### 2.5 Show the Created Sciunit Container

# %%
# !sciunit list
# Out:
#    e1 Oct 13 16:46 ipython HAND_py3.py

# %%
# !sciunit show e1
# Out:
#      id: e1
# sciunit: HAND
# command: ipython HAND_py3.py
#    size: 1.36 GB
# started: 2020-10-13 16:46
